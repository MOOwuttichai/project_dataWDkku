# %% [markdown]
# <a href="https://colab.research.google.com/github/MOOwuttichai/project_dataWDkku/blob/main/Project2_66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2 : Analyzing data from MovieLens
#
# **Due Date: Sunday, October 11**
#
# **NOTE: There are always last minute issues submitting the case studies. DO NOT WAIT UNTIL THE LAST MINUTE!**

# %% [markdown]
# ## The MovieLens data sets
#
# <img src="https://www.oreilly.com/api/v2/epubs/9781788993753/files/assets/dc0f89d7-6e9c-4790-a6c0-06725f2dbe8a.png">
#
# https://movielens.org

# %%
from IPython.lib.display import YouTubeVideo

# %%
YouTubeVideo('4tW9HY0Q460')

# %% [markdown]
# **TEAM Members:** Please EDIT this cell and add the names of all the team members in your team
#
# 1. <name> <id>
# 2. <name> <id>
# 3. <name> <id>
# 4. <name> <id>
# 5. <name> <id>

# %% [markdown]
# **Objectives**
# * In this case study we will look at the MovieLens 1M Data Set.
#     * It contains data about users and how the rate movies.
#     * http://grouplens.org/datasets/movielens/
# * The idea is to *analyze* the data set, make *conjectures*, support or refute those conjectures with *data*, and *tell a story* about the data!
#
# **Useful Readings:**
# * Chapter 14.2 (only the section on the MovieLens 1M Data Set), Chapter 5, 6.2, 7.2, 8, and 9 of the book [Python for Data Analysis](http://shop.oreilly.com/product/0636920023784.do)  (View pivately on Google Classroom).
# * If you want your code to be really compact then you might want to also look into the pivot_table method of Panda's DataFrame, though there are many other ways to complete the case study!
#
# **Required Python libraries:**
# * Pandas (pandas.pydata.org)
# * Matplotlib (matplotlib.org)
#
# **NOTE**: Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost.

# %% [markdown]
# # Problem 1:
#
# ## Importing the MovieLens data set and merging it into a single Pandas DataFrame

# %% [markdown]
# * Download the 1 million ratings data set from https://grouplens.org/datasets/movielens/1m/ (though if you are feeling adventerous you can download the 10 million ratings file instead)
# * Merge all of the data into a single Pandas DataFrame. See
#     * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
# * Store the data into an HDF5 file. See
#     * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_hdf.html
#     * https://pandas.pydata.org/docs/reference/api/pandas.read_hdf.html

# %%
from google.colab import drive
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# To mount at google drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ratings_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/ratings.dat", sep="::", header=None, names=['UserID','MovieID','Rating','Timestamp'])
movies_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/movies.dat", sep="::", header=None, names=['MovieID','Title','Genres'],encoding = "ISO-8859-1")
users_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/users.dat", sep="::", header=None, names=['UserID','Gender','Age','Occupation','Zip-code'])
# Out:
# <ipython-input-5-acac4d77af87>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/ratings.dat", sep="::", header=None, names=['UserID','MovieID','Rating','Timestamp'])
# <ipython-input-5-acac4d77af87>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/movies.dat", sep="::", header=None, names=['MovieID','Title','Genres'],encoding = "ISO-8859-1")
# <ipython-input-5-acac4d77af87>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users_dat = pd.read_table("/content/drive/MyDrive/Colab Notebooks/dataware/users.dat", sep="::", header=None, names=['UserID','Gender','Age','Occupation','Zip-code'])

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
df = ratings_dat.merge(movies_dat, how="left", on='MovieID')
df_use =df.merge(users_dat, how="left", on='UserID')
#-------------------------------
# Create a HDF5
ratings_dat.to_hdf('data.h5', key='rating')
movies_dat.to_hdf('data.h5', key='movie')
users_dat.to_hdf('data.h5', key='user')
df_use.to_hdf('data.h5', key='data_use')
#pd.read_hdf('data.h5', key= 'data_use')

# %%
#import pandas as pd
#pd.read_table("/content/drive/MyDrive/Classroom/DataWarehouseandBigDataAnalytics/users.dat", sep="::", header=None, names=['X'+str(i) for i in range(1,6)])

# %% [markdown]
# ## Report some basic details of the data you collected.  For example:
#
# *  How many movies have an average rating over 4.5 overall?
# *  How many movies have an average rating over 4.5 among men?  How about women?
# *  How many movies have an *median* rating over 4.5 among men over age 30?  How about women over age 30?
# *  What are the ten most popular movies?
#     * Choose what you consider to be a reasonable defintion of "popular".
#     * Be perpared to defend this choice.
# *  Make some conjectures(สร้างสิ่งที่อธิบายสมมุติฐาน) about how easy various groups are to please? Support your answers with data!
#     *  For example, one might conjecture that people between the ages of 1 and 10 are the easiest to please since they are all young children.  This conjecture may or may not be true, but how would you support or disprove either conclusion with with data?
#     *  Be sure to come up with your own conjectures and support them with data!

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------
#How many movies have an average rating over 4.5 overall?
average_rating = df_use[['Title','Rating']].groupby('Title').mean('Rating')
#How many movies have an average rating over 4.5 among men?  How about women?
gender_rating=df_use[['Title','Gender','Rating']]
M_rating = gender_rating[gender_rating['Gender']== 'M']
F_rating = gender_rating[gender_rating['Gender']=='F']
average_rating_M = M_rating.groupby('Title').mean()
average_rating_F = F_rating.groupby('Title').mean()
#How many movies have an median rating over 4.5 among men over age 30? How about women over age 30?
Age_rating=df_use[['Title','Age','Gender','Rating']]
over_age_30_M_rating = Age_rating[(Age_rating['Gender']== 'M') & (Age_rating['Age'] > 30)]
over_age_30_F_rating = Age_rating[(Age_rating['Gender']== 'F') & (Age_rating['Age'] > 30)]
median_rating_M = over_age_30_M_rating.groupby('Title').median()
median_rating_F = over_age_30_F_rating.groupby('Title').median()
#What are the ten most popular movies?
popular_movies_rating=df_use[['Title','Age','Gender','Rating']]
popular_movies_rating_5=popular_movies_rating[popular_movies_rating['Rating'] == 5 ]
popular_movies = popular_movies_rating_5[['Title','Rating']].groupby('Title').count().sort_values(by='Rating',ascending = False)
# Out:
# <ipython-input-8-d658bb63a804>:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_rating_M = M_rating.groupby('Title').mean()
# <ipython-input-8-d658bb63a804>:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_rating_F = F_rating.groupby('Title').mean()
# <ipython-input-8-d658bb63a804>:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_rating_M = over_age_30_M_rating.groupby('Title').median()
# <ipython-input-8-d658bb63a804>:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_rating_F = over_age_30_F_rating.groupby('Title').median()

# %% [markdown]
# #ANS 1

# %%
#How many movies have an average rating over 4.5 overall?
average_rating[average_rating['Rating'] > 4.5].count()
# Out:
# Rating    21
# dtype: int64

# %%
#How many movies have an average rating over 4.5 among men?
average_rating_M[average_rating_M['Rating'] > 4.5].count()
# Out:
# Rating    23
# dtype: int64

# %%
#How many movies have an average rating over 4.5 among women?
average_rating_F[average_rating_F['Rating'] > 4.5].count()
# Out:
# Rating    51
# dtype: int64

# %%
median_rating_M[median_rating_M['Rating'] > 4.5].count()
# Out:
# Age       86
# Rating    86
# dtype: int64

# %%
median_rating_F[median_rating_F['Rating'] > 4.5].count()
# Out:
# Age       149
# Rating    149
# dtype: int64

# %%
popular_movies.head(5)
# Out:
#                                                     Rating
# Title
# American Beauty (1999)                                1963
# Star Wars: Episode IV - A New Hope (1977)             1826
# Raiders of the Lost Ark (1981)                        1500
# Star Wars: Episode V - The Empire Strikes Back ...    1483
# Godfather, The (1972)                                 1475

# %% [markdown]
# ### เราคาดเดาว่ากลุ่ม คนที่ดู Godfather, The ส่วนมากเป็น คนอายุเกิน 56 ปี

# %%
conjecture_1 = df_use[['Title','Age']]
conjecture_1_godf = conjecture_1[conjecture_1['Title']=='Godfather, The (1972)']
conjecture_1_count = conjecture_1_godf.groupby('Age').count()
conjecture_1_count.plot(kind='bar',title='Number of people watching Godfather, The (1972) by age')
plt.show()

# %% [markdown]
# # Problem 2: Expand your investigation to histograms
#
# **An obvious issue with any inferences drawn from Problem 1 is that we did not consider how many times a movie was rated.**
# * Plot a histogram of the ratings of all movies.
# * Plot a histogram of the *number* of ratings each movie recieved.
# * Plot a histogram of the *average rating* for each movie.
# * Plot a histogram of the *average rating* for movies which are rated more than 100 times.
#     * What do you observe about the tails of the histogram where you use all the movies versus the one where you only use movies rated more than 100 times?
#     * Which highly rated movies would you trust are actually good?  Those rated more than 100 times or those rated less than 100 times?
# * Make some conjectures about the distribution of ratings? Support your answers with data!
#     *  For example, what age range do you think has more extreme ratings?  Do you think children are more or less likely to rate a movie 1 or 5?
#     *  Be sure to come up with your own conjectures and support them with data!

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------
#Plot a histogram of the ratings of all movies
df_histLL = df_use[['Title','Rating']]
df_histLL = df_histLL.set_index('Title')
plt.hist(df_histLL)
plt.title('Plot a histogram of the ratings of all movies')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
#Plot a histogram of the number of ratings each movie recieved.
df_hist = df_use[['Title','Rating']]
df_use_hist = df_hist.groupby('Title').count().sort_values(by='Rating',ascending = False)
plt.hist(df_use_hist)
plt.title('Plot a histogram of the number of ratings each movie recieved.')
plt.xlabel('ratings each movie recieved')
plt.ylabel('Frequency')
plt.show()

# %%
#Plot a histogram of the average rating for each movie.
df_hist_A = df_use[['Title','Rating']]
df_use_hist_A = df_hist_A.groupby('Title').mean()
plt.hist(df_use_hist_A)
plt.title('Plot a histogram of the average rating for each movie.')
plt.xlabel('average rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Plot a histogram of the average rating for movies which are rated more than 100 times.
df_hist2 = df_use[['MovieID','Rating']]
df_use_hist2 = df_hist2.groupby('MovieID').count().sort_values(by='Rating',ascending = False)
df_use_hist_100_MA = df_hist2.groupby('MovieID').mean()
df_use_hist_100_MARe = df_use_hist_100_MA.reset_index()
df_use_hist_100 = df_use_hist_100_MARe.merge(df_use_hist2,how = 'left',on='MovieID')
df_use_hist_100forplot = df_use_hist_100[df_use_hist_100['Rating_y'] >= 100]
use_full = df_use_hist_100forplot[['MovieID','Rating_x']]
use_full = use_full.set_index('MovieID')
plt.hist(use_full)
plt.title('Plot a histogram of the average rating for movies which are rated more than 100 times.')
plt.xlabel('average rating ')
plt.ylabel('Frequency')
plt.show()

# %%
(df_use_hist_100forplot < 100).any()
# Out:
# MovieID      True
# Rating_x     True
# Rating_y    False
# dtype: bool

# %% [markdown]
# ##เราคาดเดาว่าหนังที่ได้รับการรีวิวมากกว่า 500 ครั้งจะมีrating มากกว่า 4 ทุกเรื่อง

# %%
df_hist3 = df_use[['MovieID','Rating']]
df_use_hist3 = df_hist3.groupby('MovieID').count().sort_values(by='Rating',ascending = False)
df_use_hist_100_MA3 = df_hist3.groupby('MovieID').mean()
df_use_hist_100_MARe3 = df_use_hist_100_MA3.reset_index()
df_use_hist_1003 = df_use_hist_100_MARe3.merge(df_use_hist3,how = 'left',on='MovieID')
df_use_hist_100forplot3 = df_use_hist_1003[df_use_hist_1003['Rating_y'] >= 1000]
use_full3 = df_use_hist_100forplot3[['MovieID','Rating_x']]
use_full3 = use_full3.set_index('MovieID')
plt.hist(use_full3)
plt.title('Plot a histogram of the average rating for movies which are rated more than 1000 times.')
plt.xlabel('average rating ')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #test code

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with a 'movie_id' and 'num_ratings' column
# Replace this with your actual DataFrame and column names

# Example DataFrame
data = {'movie_id': [1, 2, 3, 4, 5,6],
        'num_ratings': [100, 200, 150, 300, 50,100]}

df = pd.DataFrame(data)

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(df['num_ratings'], bins=20, edgecolor='k', alpha=0.7)
plt.title('Histogram of Number of Ratings per Movie')
plt.xlabel('Number of Ratings')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df_histLL
# Out:
#                                         Rating
# Title
# One Flew Over the Cuckoo's Nest (1975)       5
# James and the Giant Peach (1996)             3
# My Fair Lady (1964)                          3
# Erin Brockovich (2000)                       4
# Bug's Life, A (1998)                         5
# ...                                        ...
# Weekend at Bernie's (1989)                   1
# Crying Game, The (1992)                      5
# Welcome to the Dollhouse (1995)              5
# Sophie's Choice (1982)                       4
# E.T. the Extra-Terrestrial (1982)            4
#
# [1000209 rows x 1 columns]

# %% [markdown]
# # Problem 3:
# ## Correlation:  Men versus women
#
# Let look more closely at the relationship between the pieces of data we have.

# %% [markdown]
# * Make a scatter plot of men versus women and their mean rating for every movie.
# * Make a scatter plot of men versus women and their mean rating for movies rated more than 200 times.
# * Compute the *correlation coefficent* between the ratings of men and women.
#     * What do you observe?
#     * Are the ratings similiar or not? Support your answer with data!
# * Conjecture under what circumstances the rating given by one gender can be used to predict the rating given by the other gender.
#     * For example, are men and women more similar when they are younger or older?
#     * Be sure to come up with your own conjectures and support them with data!

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib

# %% [markdown]
# ### A scatter plot of men versus women and their mean rating for every movie

# %%
#-------------------------------
data_M_and_F = df_use[['Title','Gender','Rating']]
data_Male = data_M_and_F[data_M_and_F['Gender']=='M']
data_Female = data_M_and_F[data_M_and_F['Gender']=='F']
data_Male_Mean = data_Male.groupby('Title').mean()
data_Female_Mean = data_Female.groupby('Title').mean()
data_plot = data_Male_Mean.merge(data_Female_Mean,how='left',on='Title')
data_plot_nonna = data_plot.dropna()
plt.scatter(data_plot_nonna['Rating_x'], data_plot_nonna['Rating_y'])
plt.title('A scatter plot of men VS. women and their mean rating for every movie')
plt.xlabel('mean rating men')
plt.ylabel('mean rating women')
plt.show()
#-------------------------------
# Out:
# <ipython-input-25-0f0e4da2bbbf>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Male_Mean = data_Male.groupby('Title').mean()
# <ipython-input-25-0f0e4da2bbbf>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Female_Mean = data_Female.groupby('Title').mean()

# %%
data_plot_nonna
# Out:
#                                    Rating_x  Rating_y
# Title
# $1,000,000 Duck (1971)             2.761905  3.375000
# 'Night Mother (1986)               3.352941  3.388889
# 'Til There Was You (1997)          2.733333  2.675676
# 'burbs, The (1989)                 2.962085  2.793478
# ...And Justice for All (1979)      3.689024  3.828571
# ...                                     ...       ...
# Your Friends and Neighbors (1998)  3.536585  2.888889
# Zed & Two Noughts, A (1985)        3.380952  3.500000
# Zero Effect (1998)                 3.723140  3.864407
# Zeus and Roxanne (1997)            2.357143  2.777778
# eXistenZ (1999)                    3.289086  3.098592
#
# [3446 rows x 2 columns]

# %% [markdown]
# ### A scatter plot of men versus women and their mean rating for movies rated more than 200 times

# %%
#-------------------------------------------------------------------------------------
data_MF = df_use[['Title','Gender','Rating']]
data_MF1 = data_MF[['Title','Rating']]
data_MF2 = data_MF1.groupby('Title').count().sort_values(by='Rating',ascending = False)
data_MF3 = data_MF2.reset_index()
#---------------------------------------------------------------------------------------
data_Male = data_M_and_F[data_M_and_F['Gender']=='M']
data_Female = data_M_and_F[data_M_and_F['Gender']=='F']
data_Male_Mean = data_Male.groupby('Title').mean()
data_Female_Mean = data_Female.groupby('Title').mean()
#-------------------------------------------------------------------------------------------
data_MF4 = data_MF3.merge(data_Male_Mean,how='left',on='Title')
data_MF5 = data_MF3.merge(data_Female_Mean,how='left',on='Title')
#----------------------------------------------------------------------------------------
data_MF4_1 = data_MF4[data_MF4['Rating_x'] >= 200]
use_full_M = data_MF4_1[['Title','Rating_y']]
use_full_M = use_full_M.set_index('Title')
#---------------------------------------------------------------------------------------
data_MF5_1 = data_MF5[data_MF5['Rating_x'] >= 200]
use_full_F = data_MF5_1[['Title','Rating_y']]
use_full_F = use_full_F.set_index('Title')
#--------------------------------------------------------------------------------------
plt.scatter(use_full_M, use_full_F)
plt.title('A scatter plot of men VS. women and their mean rating for every movie')
plt.xlabel('mean rating men')
plt.ylabel('mean rating women')
plt.show()
# Out:
# <ipython-input-27-501d20c7c660>:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Male_Mean = data_Male.groupby('Title').mean()
# <ipython-input-27-501d20c7c660>:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Female_Mean = data_Female.groupby('Title').mean()

# %% [markdown]
# ### The correlation coefficent between the ratings of men and women

# %%
#-------------------------------
# The correlation mean rating for every movie
print(np.corrcoef(data_plot_nonna['Rating_x'],data_plot_nonna['Rating_y']))
#-------------------------------
# The correlation movies rated more than 200 times
print(np.corrcoef(use_full_M['Rating_y'],use_full_F['Rating_y']))
# Out:
# [[1.         0.76318989]
#  [0.76318989 1.        ]]
# [[1.         0.91896272]
#  [0.91896272 1.        ]]

# %% [markdown]
# ## Conjecture under what circumstances the rating given by one gender can be used to predict the rating given by the other gender
#
# Example<br>
# Conjecture 1: Men and women are more similar when they are older, consider their rating over the same genres.
#
# Conjecture 2: Men and women more similar when they are academic/educator, artist, college/grad student, and programmer.
#
# Conjecture 3: Men and women more similar when they watch Action, Drama, War, and Triller.

# %% [markdown]
# #Conjecture ความสัมพันธ์ระหว่างชายเเละหญิงที่ทำอาชีพ scientist,programmer,doctor/health care การให้ rating

# %%
#-------------------------------
data_3_3 = df_use[['Title','Gender','Occupation','Rating']]
data_3_scientist = data_3_3[data_3_3['Occupation']==15]
data_3_programmer = data_3_3[data_3_3['Occupation']==12]
data_3_doctor = data_3_3[data_3_3['Occupation']==6]
#-------------------------------
#scientist
data_3_scientist_TR = data_3_scientist[['Title','Gender','Rating']]
data_Male_scientist = data_3_scientist_TR[data_M_and_F['Gender']=='M']
data_Femal_scientist = data_3_scientist_TR[data_M_and_F['Gender']=='F']
data_Male_scientist_Mean = data_Male_scientist.groupby('Title').mean()
data_Female_scientist_Mean = data_Femal_scientist.groupby('Title').mean()
data_plot_scientist = data_Male_scientist_Mean.merge(data_Female_scientist_Mean,how='left',on='Title')
data_plot_scientist_nonna = data_plot_scientist.dropna()
plt.scatter(data_plot_scientist_nonna['Rating_x'], data_plot_scientist_nonna['Rating_y'])
#programmer
data_3_programmer_TR = data_3_programmer[['Title','Gender','Rating']]
data_Male_programmer = data_3_programmer_TR[data_M_and_F['Gender']=='M']
data_Femal_programmer = data_3_programmer_TR[data_M_and_F['Gender']=='F']
data_Male_programmer_Mean = data_Male_programmer.groupby('Title').mean()
data_Female_programmer_Mean = data_Femal_programmer.groupby('Title').mean()
data_plot_programmer = data_Male_programmer_Mean.merge(data_Female_programmer_Mean,how='left',on='Title')
data_plot_programmer_nonna = data_plot_programmer.dropna()
plt.scatter(data_plot_programmer_nonna['Rating_x'], data_plot_programmer_nonna['Rating_y'])
#doctor
data_3_doctor_TR = data_3_doctor[['Title','Gender','Rating']]
data_Male_doctor = data_3_doctor_TR[data_M_and_F['Gender']=='M']
data_Femal_doctor = data_3_doctor_TR[data_M_and_F['Gender']=='F']
data_Male_doctor_Mean = data_Male_doctor.groupby('Title').mean()
data_Female_doctor_Mean = data_Femal_doctor.groupby('Title').mean()
data_plot_doctor = data_Male_doctor_Mean.merge(data_Female_doctor_Mean,how='left',on='Title')
data_plot_doctor_nonna = data_plot_doctor.dropna()
plt.scatter(data_plot_doctor_nonna['Rating_x'], data_plot_doctor_nonna['Rating_y'])
#-------------------------------------------------------------------------------------------------------------------------
#scientist
print(np.corrcoef(data_plot_scientist_nonna['Rating_x'],data_plot_scientist_nonna['Rating_y']))
#programmer
print(np.corrcoef(data_plot_programmer_nonna['Rating_x'],data_plot_programmer_nonna['Rating_y']))
#doctor
print(np.corrcoef(data_plot_doctor_nonna['Rating_x'],data_plot_doctor_nonna['Rating_y']))
# Out:
# <ipython-input-29-545c9baeac13>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Male_scientist = data_3_scientist_TR[data_M_and_F['Gender']=='M']
# <ipython-input-29-545c9baeac13>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Femal_scientist = data_3_scientist_TR[data_M_and_F['Gender']=='F']
# <ipython-input-29-545c9baeac13>:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Male_scientist_Mean = data_Male_scientist.groupby('Title').mean()
# <ipython-input-29-545c9baeac13>:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Female_scientist_Mean = data_Femal_scientist.groupby('Title').mean()
# <ipython-input-29-545c9baeac13>:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Male_programmer = data_3_programmer_TR[data_M_and_F['Gender']=='M']
# <ipython-input-29-545c9baeac13>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Femal_programmer = data_3_programmer_TR[data_M_and_F['Gender']=='F']
# <ipython-input-29-545c9baeac13>:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Male_programmer_Mean = data_Male_programmer.groupby('Title').mean()
# <ipython-input-29-545c9baeac13>:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Female_programmer_Mean = data_Femal_programmer.groupby('Title').mean()
# <ipython-input-29-545c9baeac13>:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Male_doctor = data_3_doctor_TR[data_M_and_F['Gender']=='M']
# <ipython-input-29-545c9baeac13>:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_Femal_doctor = data_3_doctor_TR[data_M_and_F['Gender']=='F']
# <ipython-input-29-545c9baeac13>:29: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Male_doctor_Mean = data_Male_doctor.groupby('Title').mean()
# <ipython-input-29-545c9baeac13>:30: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_Female_doctor_Mean = data_Femal_doctor.groupby('Title').mean()
# [[1.         0.47962135]
#  [0.47962135 1.        ]]
# [[1.         0.45008376]
#  [0.45008376 1.        ]]
# [[1.         0.51847883]
#  [0.51847883 1.        ]]

# %% [markdown]
# # Problem 4:
# ## Open Ended Question:  Business Intelligence

# %% [markdown]
# * Do any of your conjectures in Problems 1, 2, and 3 provide insights that a movie company might be interested in?
# * Propose a business question that you think this data can answer.
# * Suppose you are a Data Sciencetist at a movie company.  **Convince your boss that your conjecture is correct!**

# %% [markdown]
# ### For example, which movie to make/buy? (seperating via Genre?)

# %% [markdown]
# #เมื่อทางโรงหนังต้องการสร้างหนังใหม่เเต่อยากทราบว่ากลุ่มคนอายุ 56 ขึ้นชอบดูหนังเเบบไหน 10 อันดับเเรก เเล้ว 2 อาชีพที่ดูหนังเเนวนั้นมากสุดมีการให้ rating ที่สัมพันธ์กันไหม โดยเราจะเอาหนังที่ถูกรีวิวมากกว่า 10 ครั้ง

# %%
#-------------------------------
data_4 = df_use[['Title','Age','Occupation','Genres','Rating']]
data_4_claen_Age = data_4[data_4['Age'] == 56]
data_4_claen_Age['count'] = range(len(data_4_claen_Age))
data_4_claen_Age_C = data_4_claen_Age[['Occupation','count']]
data_4_claen_Age_count = data_4_claen_Age_C.groupby('Occupation').count().sort_values(by='count',ascending = False)
data_4_claen_Age_count.head(2)
#-------------------------------
# Out:
# <ipython-input-51-a00df501be72>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_4_claen_Age['count'] = range(len(data_4_claen_Age))
#             count
# Occupation
# 13           8703
# 1            5574

# %%
data_4_claen_Genres = data_4[data_4['Age'] == 56]
data_4_claen_Genres['count'] = range(len(data_4_claen_Age))
data_4_claen_Genres_C = data_4_claen_Age[['Genres','count']]
data_4_claen_Genres_count =data_4_claen_Genres_C.groupby('Genres').count().sort_values(by='count',ascending = False).reindex()
data_4_claen_Genres_count.head(10)
# Out:
# <ipython-input-52-a476a552891e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_4_claen_Genres['count'] = range(len(data_4_claen_Age))
#                   count
# Genres
# Drama              6085
# Comedy             3554
# Comedy|Drama       1702
# Comedy|Romance     1654
# Drama|Romance      1415
# Drama|War           916
# Drama|Thriller      778
# Action|Thriller     728
# Thriller            644
# Action|Drama|War    624

# %%
data_4_claen_Age_TOP2 = data_4_claen_Age[(data_4_claen_Age['Occupation']== 13) | (data_4_claen_Age['Occupation']==1)]
data_TOP = data_4_claen_Age_TOP2[['Title','Occupation','Rating']]
data_academic = data_TOP[data_TOP['Occupation']== 13]
data_academic1 = data_academic[['Title','Rating']]
data_retired = data_TOP[data_TOP['Occupation']==1]
data_retired1 = data_retired[['Title','Rating']]
#--------------------------------------------------------------------------------------
data_academic2 = data_academic1.groupby('Title').count().sort_values(by='Rating',ascending = False)
data_academic3 = data_academic2.reset_index()
data_retired2 = data_retired1.groupby('Title').count().sort_values(by='Rating',ascending = False)
data_retired3 = data_retired2.reset_index()
#--------------------------------------------------------------------------------------
data_academic_Mean = data_academic1.groupby('Title').mean()
data_retired_Mean = data_retired1.groupby('Title').mean()
#-------------------------------------------------------------------------------------------
data_academic4 = data_academic3.merge(data_academic_Mean,how='left',on='Title')
data_retired4 = data_retired3.merge(data_retired_Mean,how='left',on='Title')
#----------------------------------------------------------------------------------------
data_academic5 = data_academic4[data_academic4['Rating_x'] >= 10]
use_data_academic5 = data_academic5[['Title','Rating_y']]
#use_data_academic5 = use_data_academic5.set_index('Title')
#---------------------------------------------------------------------------------------
data_retired5 = data_retired4[data_retired4['Rating_x'] >= 10]
use_data_retired5 = data_retired5[['Title','Rating_y']]
#use_data_retired5 = use_data_retired5.set_index('Title')
#---------------------------------------------------------------------------------------
data_plot_Occupation = use_data_academic5.merge(use_data_retired5,how='left',on='Title')
data_plot_Occupation_nonna = data_plot_Occupation.dropna()
plt.scatter(data_plot_Occupation_nonna['Rating_y_x'], data_plot_Occupation_nonna['Rating_y_y'])
print(np.corrcoef(data_plot_Occupation_nonna['Rating_y_x'],data_plot_Occupation_nonna['Rating_y_y']))
# Out:
# [[1.         0.60016582]
#  [0.60016582 1.        ]]

# %%
data_plot_Occupation
# Out:
#                                   Title  Rating_y_x  Rating_y_y
# 0                American Beauty (1999)    4.056604    3.880000
# 1               Schindler's List (1993)    4.650000    4.266667
# 2            Shakespeare in Love (1998)    3.647059    4.150000
# 3             Gone with the Wind (1939)    4.470588    4.000000
# 4            Saving Private Ryan (1998)    4.562500    4.266667
# ..                                  ...         ...         ...
# 232  Four Weddings and a Funeral (1994)    3.800000    3.785714
# 233              What About Bob? (1991)    3.700000         NaN
# 234                  Raging Bull (1980)    3.900000         NaN
# 235                      28 Days (2000)    3.400000         NaN
# 236                      Cabaret (1972)    4.600000         NaN
#
# [237 rows x 3 columns]

# %%
data_retired_Mean
# Out:
#                                      Rating
# Title
# ...And Justice for All (1979)      4.000000
# 10 Things I Hate About You (1999)  4.000000
# 101 Dalmatians (1961)              2.500000
# 12 Angry Men (1957)                4.142857
# 13th Warrior, The (1999)           1.000000
# ...                                     ...
# Young Doctors in Love (1982)       4.000000
# Young Frankenstein (1974)          4.166667
# Young Sherlock Holmes (1985)       3.000000
# Zero Effect (1998)                 3.000000
# eXistenZ (1999)                    3.000000
#
# [1711 rows x 1 columns]

# %% [markdown]
# # Done!
#
# **What do you need to submit?**
#
# * **Notebook File**: This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook.
#
#
# * **PPT Slides**: please prepare PPT slides (10 minutes)
#     * Motivation about the data collection, why the topic is interesting to you. อธิบายเกี่ยวกับข้อมูล สร้างแรงบันดาลใจเดี่ยวกับข้อมูลให้ผู้รับฟัง ให้ผู้ฟังเข้าใจความเป็นมาและความสำคัญของข้อมูล
#     * What is the relationship between this topic and Business Intelligence?
#     * How did you analyse the data?
#     * What conjectures did you make and how did you support or disprove them using data?
#     * Communicating Results with figures or tables
#     * Did you find anything suprising in the data?
#     * What business decision do you think this data could help answer?  Why?
#
#      (please include figures or tables in the report)
#
# **How to submit:**
#
#         ส่ง link ของ ipynb และ slides ในรูปแบบ pdf ใน Google Classroom
#
# **Note: Each team just needs only one submission**
